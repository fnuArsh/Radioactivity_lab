# %% [markdown]
# <a href="https://colab.research.google.com/github/fnuArsh/Radioactivity_lab/blob/main/lab6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Replace 'file_name.csv' with the name of your CSV file
df = pd.read_csv('Book5.csv')

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#    Shelf#  Counts  Coor. Counts  distance(cm)  Shelf ratios  inverse   \
# 0       1   25299         25287             2         1.450  0.500000
# 1       2   17449         17437             4         1.000  0.250000
# 2       3   12153         12141             6         0.696  0.166667
# 3       4    8765          8753             8         0.502  0.125000
# 4       5    6344          6332            10         0.363  0.100000
#
#    inverse corr.  Inverse sq.   inverse sq.corr.  inverse counts  \
# 0       1.450000      0.250000          1.450000        25287.00
# 1       0.725000      0.062500          0.362500        12643.50
# 2       0.483333      0.027778          0.161111         8429.00
# 3       0.362500      0.015625          0.090625         6321.75
# 4       0.290000      0.010000          0.058000         5057.40
#
#    inverse sq. counts
# 0         25287.000000
# 1          6321.750000
# 2          2809.666667
# 3          1580.437500
# 4          1011.480000

# %%
x =df.iloc[:, 3]
y1= df.iloc[:, 2]
y2 = df.iloc[:, 4]
y1_inverse=df.iloc[:, 9]
y1_inverse_square=df.iloc[:, 10]
y2_inverse=df.iloc[:, 6]
y2_inverse_square=df.iloc[:, 8]

# %%
plt.plot(x, y1, label='experimental')

# Plot x vs y1_inverse
plt.plot(x, y1_inverse, label='predicted 1/x')

# Plot x vs y1_inverse_square
plt.plot(x, y1_inverse_square, label='predicted 1/x^2')

# Add labels and legend
plt.xlabel('distance(cm)')
plt.ylabel('counts')
plt.title('Plot of distance vs counts ')
plt.legend()
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.plot(x, y2, label='experimental')

# Plot x vs y1_inverse
plt.plot(x, y2_inverse, label='predicted 1/x')

# Plot x vs y1_inverse_square
plt.plot(x, y2_inverse_square, label='predicted 1/x^2')

# Add labels and legend
plt.xlabel('distance(cm)')
plt.ylabel('shelf-ratio(wrt #2)')
plt.title('plot of distance vs shelf ratios ')
plt.legend()
plt.grid(True)
# Show the plot
plt.show()
